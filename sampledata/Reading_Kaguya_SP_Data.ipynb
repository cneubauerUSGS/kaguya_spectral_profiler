# %% [markdown]
# # Reading SP Data
#
# The Spectral Profiler data is available in archives with `.sl2` file endings.  These files are

# %%
import tarfile
import glob

import sys
sys.path.insert(0, "/data/plio/")
import plio

# %% [markdown]
# ## Data Extraction
# Only the .spc file is truly needed here.  We want to keep a link to the underlying jpg, but those are simply the same file name with .jpg attched.  I also wonder how much value we have in keeping those around at all?  Something to decide in the future.

# %%
files = glob.glob('*.sl2')
for f in files:
    tar = tarfile.open(f)
    # Extract the spc and the ctg files
    list(map(tar.extract, [m for m in tar.getmembers() if '.spc' in m.name])

# %%
from plio.io.io_spectral_profiler import Spectral_Profiler

# %%
s = Spectral_Profiler('SP_2C_02_05494_N704_E2143.spc')

# %%
s.label
# Out:
# PVLModule([
#   ('PDS_VERSION_ID', 'PDS3')
#   ('RECORD_TYPE', 'UNDEFINED')
#   ('FILE_NAME', 'SP_2C_02_05494_N704_E2143.spc')
#   ('PRODUCT_ID', 'SP_2C_02_05494_N704_E2143')
#   ('DATA_FORMAT', 'PDS')
#   ('^ANCILLARY_AND_SUPPLEMENT_DATA', Units(value=24730, units='BYTES'))
#   ('^SP_SPECTRUM_WAV', Units(value=31038, units='BYTES'))
#   ('^SP_SPECTRUM_RAW', Units(value=31630, units='BYTES'))
#   ('^SP_SPECTRUM_REF2', Units(value=54126, units='BYTES'))
#   ('^SP_SPECTRUM_RAD', Units(value=76622, units='BYTES'))
#   ('^SP_SPECTRUM_REF1', Units(value=99118, units='BYTES'))
#   ('^SP_SPECTRUM_QA', Units(value=121614, units='BYTES'))
#   ('^L2D_RESULT_ARRAY', Units(value=144110, units='BYTES'))
#   ('SOFTWARE_NAME', 'RGC_SP')
#   ('SOFTWARE_VERSION', '2.10.3')
#   ('PROCESS_VERSION_ID', 'L2C')
#   ('PRODUCT_CREATION_TIME',
#    datetime.datetime(2012, 4, 20, 16, 24, 43, tzinfo=<UTC>))
#   ('PROGRAM_START_TIME', datetime.datetime(2012, 4, 20, 16, 19, 31, tzinfo=<UTC>))
#   ('PRODUCER_ID', 'LISM')
#   ('PRODUCT_SET_ID', 'SP_Level2C')
#   ('PRODUCT_VERSION_ID', '02')
#   ('REGISTERED_PRODUCT', 'Y')
#   ('LEVEL2B1_FILE_NAME', 'SP_2B1_02_05494_1DN0E03376R.spc')
#   ('SOURCE_FILE_NAME', 'SP_2B2_02_05494_N684_E2150.spc')
#   ('SPICE_METAKERNEL_FILE_NAME',
#    'RGC_INF_TCv401IK_MIv200IK_SPv105IK_RISE100h_02_LongCK_D_V02_de421_110706.mk')
#   ('MISSION_NAME', 'SELENE')
#   ('SPACECRAFT_NAME', 'SELENE-M')
#   ('DATA_SET_ID', 'SELENE_Moon_SP_Level2C')
#   ('INSTRUMENT_NAME', 'Spectral Profiler')
#   ('INSTRUMENT_ID', 'SP')
#   ('MISSION_PHASE_NAME', 'Extended')
#   ('REVOLUTION_NUMBER', 5494)
#   ('STRIP_SEQUENCE_NUMBER', 3)
#   ('SCENE_SEQUENCE_NUMBER', 38)
#   ('REV_STRIP_SCENE', 'N/A')
#   ('TARGET_NAME', 'MOON')
#   ('OBSERVATION_MODE_ID', 'OBS-NORMAL')
#   ('SENSOR_DESCRIPTION',
#    'SP is a nadir-looking spectrometer which has a reflective telescope, two '
#    'plane gratings, and three 128-element detectors covering 296 bands in 500 - '
#    '2600 nm. The first detector is Si PIN photodiode, and the rest are InGaAs.')
#   ('SENSOR_DESCRIPTION2', 'SP SENSOR DESCRIPTION2')
#   ('EXPOSURE_MODE_ID', 'LONG')
#   ('SHORT_EXPOSURE_DURATION', Units(value=26.0, units='msec'))
#   ('LONG_EXPOSURE_DURATION', Units(value=77.0, units='msec'))
#   ('CALIBRATION_MODE_ID', 'NONE')
#   ('SPACECRAFT_CLOCK_START_COUNT', Units(value=914831697.718, units='sec'))
#   ('SPACECRAFT_CLOCK_STOP_COUNT', Units(value=914831711.1858, units='sec'))
#   ('START_TIME', datetime.datetime(2009, 1, 1, 7, 55, 8, 762645, tzinfo=<UTC>))
#   ('STOP_TIME', datetime.datetime(2009, 1, 1, 7, 55, 22, 230449, tzinfo=<UTC>))
#   ('UPPER_LEFT_LATITUDE', Units(value=70.740452, units='deg'))
#   ('UPPER_LEFT_LONGITUDE', Units(value=214.283706, units='deg'))
#   ('UPPER_RIGHT_LATITUDE', Units(value=70.740452, units='deg'))
#   ('UPPER_RIGHT_LONGITUDE', Units(value=214.283706, units='deg'))
#   ('LOWER_LEFT_LATITUDE', Units(value=70.050685, units='deg'))
#   ('LOWER_LEFT_LONGITUDE', Units(value=214.254857, units='deg'))
#   ('LOWER_RIGHT_LATITUDE', Units(value=70.050685, units='deg'))
#   ('LOWER_RIGHT_LONGITUDE', Units(value=214.254857, units='deg'))
#   ('LOCATION_FLAG', 'D')
#   ('ROLL_CANT', 'YES')
#   ('MOON_SUN_DISTANCE', Units(value=146860179, units='km'))
#   ('VIS_FOCAL_PLANE_TEMPERATURE', Units(value=13.48, units='degC'))
#   ('N1_FOCAL_PLANE_TEMPERATURE', Units(value=10.33, units='degC'))
#   ('N2_FOCAL_PLANE_TEMPERATURE', Units(value=243.0, units='K'))
#   ('SATELLITE_MOVING_DIRECTION', '-1')
#   ('A_AXIS_RADIUS', Units(value=1737.4, units='km'))
#   ('B_AXIS_RADIUS', Units(value=1737.4, units='km'))
#   ('C_AXIS_RADIUS', Units(value=1737.4, units='km'))
#   ('SPACECRAFT_ALTITUDE', Units(value=96.631, units='km'))
#   ('SPACECRAFT_GROUND_SPEED', Units(value=1.546, units='km/sec'))
#   ('VIS_BAND_NUMBER', 84)
#   ('VIS_SPECTRAL_COVERAGE', Units(value=[482.6, 980.6], units='nm'))
#   ('VIS_BAND_WIDTH', Units(value=6.0, units='nm'))
#   ('N1_BAND_NUMBER', 100)
#   ('N1_SPECTRAL_COVERAGE', Units(value=[894.4, 1688.9], units='nm'))
#   ('N1_BAND_WIDTH', Units(value=8.0, units='nm'))
#   ('N2_BAND_NUMBER', 112)
#   ('N2_SPECTRAL_COVERAGE', Units(value=[1694.9, 2583.1], units='nm'))
#   ('N2_BAND_WIDTH', Units(value=8.0, units='nm'))
#   ('PROCESS_PARAMETER_FILE_NAME', 'SP_higher_level_proc_param.txt')
#   ('DAYTIME_EQUATOR_CROSSING_LON', 'N/A')
#   ('IMAGER', 'MV2')
#   ('TM_DATA_SET_NAME', 'MVA2A0_02NM05494_003_0038.sl2')
#   ('TM_CORRECTED_START_TIME',
#    datetime.datetime(2009, 1, 1, 7, 55, 11, 931045, tzinfo=<UTC>))
#   ('TM_CORRECTED_STOP_TIME',
#    datetime.datetime(2009, 1, 1, 7, 55, 25, 957982, tzinfo=<UTC>))
#   ('TM_CORRECTED_SAMPLING_INTERVAL', Units(value=12.999893, units='msec'))
#   ('TM_LINES', 1080)
#   ('TM_LINE_SAMPLES', 962)
#   ('TM_FIRST_PIXEL_NUMBER', 1)
#   ('TM_LAST_PIXEL_NUMBER', 962)
#   ('TM_UPPER_LEFT_LATITUDE', Units(value=68.778097, units='deg'))
#   ('TM_UPPER_LEFT_LONGITUDE', Units(value=215.93075, units='deg'))
#   ('TM_UPPER_RIGHT_LATITUDE', Units(value=68.795981, units='deg'))
#   ('TM_UPPER_RIGHT_LONGITUDE', Units(value=214.18109, units='deg'))
#   ('TM_LOWER_LEFT_LATITUDE', Units(value=68.061612, units='deg'))
#   ('TM_LOWER_LEFT_LONGITUDE', Units(value=215.845451, units='deg'))
#   ('TM_LOWER_RIGHT_LATITUDE', Units(value=68.078508, units='deg'))
#   ('TM_LOWER_RIGHT_LONGITUDE', Units(value=214.153956, units='deg'))
#   ('TM_SATURATED_PIXEL_PERCENTAGE', 0)
#   ('TM_DEAD_PIXEL_PERCENTAGE', 0)
#   ('TM_SHADOWED_AREA_PIXEL_PERCENTAGE', 0)
#   ('HIGH_SP_POINT_NUM', 0)
#   ('NORMAL_SP_POINT_NUM', 38)
#   ('UPPER_MARGIN_POINT_NUM', 'N/A')
#   ('LOWER_MARGIN_POINT_NUM', 'N/A')
#   ('CAL_LAMP_INFO', 'N/A')
#   ('MATCHING_ACCURACY_INFO', '0100')
#   ('ANCILLARY_AND_SUPPLEMENT_DATA',
#    {'COLUMN': {'BYTES': 8,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SPACECRAFT_CLOCK_COUNT',
#                'START_BYTE': 1,
#                'UNIT': 'sec'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'VIS_FOCAL_PLANE_TEMPERATURE',
#                'START_BYTE': 9,
#                'UNIT': 'degC'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'NIR1_FOCAL_PLANE_TEMPERATURE',
#                'START_BYTE': 13,
#                'UNIT': 'degC'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'NIR2_FOCAL_PLANE_TEMPERATURE',
#                'START_BYTE': 17,
#                'UNIT': 'K'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SPECTROMETER_TEMPERATURE_1',
#                'START_BYTE': 21,
#                'UNIT': 'degC'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SPECTROMETER_TEMPERATURE_2',
#                'START_BYTE': 25,
#                'UNIT': 'degC'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SPECTROMETER_TEMPERATURE_3',
#                'START_BYTE': 29,
#                'UNIT': 'degC'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SPECTROMETER_TEMPERATURE_4',
#                'START_BYTE': 33,
#                'UNIT': 'degC'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'HALOGEN_BULB_RADIANCE',
#                'START_BYTE': 37,
#                'UNIT': 'V'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'HALOGEN_BULB_VOLTAGE1',
#                'START_BYTE': 41,
#                'UNIT': 'V'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'HALOGEN_BULB_VOLTAGE2',
#                'START_BYTE': 45,
#                'UNIT': 'V'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'HALOGEN_BULB_TEMPERATURE1',
#                'START_BYTE': 49,
#                'UNIT': 'degC'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'HALOGEN_BULB_TEMPERATURE2',
#                'START_BYTE': 53,
#                'UNIT': 'degC'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SPACECRAFT_ALTITUDE',
#                'START_BYTE': 57,
#                'UNIT': 'km'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SPACECRAFT_GROUND_SPEED',
#                'START_BYTE': 61,
#                'UNIT': 'km/sec'},
#     'COLUMN': {'BYTES': 8,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SUB_SPACECRAFT_LATITUDE',
#                'START_BYTE': 65,
#                'UNIT': 'deg'},
#     'COLUMN': {'BYTES': 8,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SUB_SPACECRAFT_LONGITUDE',
#                'START_BYTE': 73,
#                'UNIT': 'deg'},
#     'COLUMN': {'BYTES': 8,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'CENTER_LATITUDE',
#                'START_BYTE': 81,
#                'UNIT': 'deg'},
#     'COLUMN': {'BYTES': 8,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'CENTER_LONGITUDE',
#                'START_BYTE': 89,
#                'UNIT': 'deg'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'EMISSION_ANGLE',
#                'START_BYTE': 97,
#                'UNIT': 'deg'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SPACECRAFT_AZIMUTH',
#                'START_BYTE': 101,
#                'UNIT': 'deg'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'INCIDENCE_ANGLE',
#                'START_BYTE': 105,
#                'UNIT': 'deg'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SOLAR_AZIMUTH_ANGLE',
#                'START_BYTE': 109,
#                'UNIT': 'deg'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'PHASE_ANGLE',
#                'START_BYTE': 113,
#                'UNIT': 'deg'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SP_TEMPERATURE',
#                'START_BYTE': 117,
#                'UNIT': 'degC'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SP_PELTIER_HOT_TEMPERATURE',
#                'START_BYTE': 121,
#                'UNIT': 'degC'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SP_N2_RADIATOR_TEMPERATURE',
#                'START_BYTE': 125,
#                'UNIT': 'degC'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SP_CAL_VIS_TEMPERATURE',
#                'START_BYTE': 129,
#                'UNIT': 'degC'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SP_CAL_NIR_TEMPERATURE',
#                'START_BYTE': 133,
#                'UNIT': 'degC'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'DPU_TEMPERATURE',
#                'START_BYTE': 137,
#                'UNIT': 'degC'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SP_POWER_P5V',
#                'START_BYTE': 141,
#                'UNIT': 'V'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SP_POWER_M15V',
#                'START_BYTE': 145,
#                'UNIT': 'V'},
#     'COLUMN': {'BYTES': 4,
#                'DATA_TYPE': 'IEEE_REAL',
#                'NAME': 'SP_POWER_P15V',
#                'START_BYTE': 149,
#                'UNIT': 'V'},
#     'COLUMN': {'BYTES': 1,
#                'DATA_TYPE': 'MSB_INTEGER',
#                'NAME': 'CALIBRATION',
#                'START_BYTE': 153,
#                'UNIT': 'N/A'},
#     'COLUMN': {'BYTES': 1,
#                'DATA_TYPE': 'MSB_INTEGER',
#                'NAME': 'SP_PELTIER',
#                'START_BYTE': 154,
#                'UNIT': 'N/A'},
#     'COLUMN': {'BYTES': 1,
#                'DATA_TYPE': 'MSB_INTEGER',
#                'NAME': 'TC_MI_STATUS',
#                'START_BYTE': 155,
#                'UNIT': 'N/A'},
#     'COLUMN': {'BYTES': 1,
#                'DATA_TYPE': 'MSB_INTEGER',
#                'NAME': 'CLOCK_COUNT_ERR_FLAG',
#                'START_BYTE': 156,
#                'UNIT': 'N/A'},
#     'COLUMN': {'BYTES': 1,
#                'DATA_TYPE': 'MSB_UNSIGNED_INTEGER',
#                'NAME': 'SPATIAL_RESOLUTION_FLAG',
#                'START_BYTE': 157,
#                'UNIT': 'N/A'},
#     'COLUMN': {'BYTES': 1,
#                'DATA_TYPE': 'MSB_UNSIGNED_INTEGER',
#                'NAME': 'GEOMETRIC_INFO_RECAL_FLAG',
#                'START_BYTE': 158,
#                'UNIT': 'N/A'},
#     'COLUMN': {'BYTES': 2,
#                'DATA_TYPE': 'MSB_UNSIGNED_INTEGER',
#                'NAME': 'SUPPORT_IMAGE_LINE_POSITION',
#                'START_BYTE': 159,
#                'UNIT': 'N/A'},
#     'COLUMN': {'BYTES': 2,
#                'DATA_TYPE': 'MSB_UNSIGNED_INTEGER',
#                'NAME': 'SUPPORT_IMAGE_COLUMN_POSITION',
#                'START_BYTE': 161,
#                'UNIT': 'N/A'},
#     'COLUMN': {'BYTES': 2,
#                'DATA_TYPE': 'MSB_UNSIGNED_INTEGER',
#                'NAME': 'THUMBNAIL_LINE_POSITION',
#                'START_BYTE': 163,
#                'UNIT': 'N/A'},
#     'COLUMN': {'BYTES': 2,
#                'DATA_TYPE': 'MSB_UNSIGNED_INTEGER',
#                'NAME': 'THUMBNAIL_COLUMN_POSITION',
#                'START_BYTE': 165,
#                'UNIT': 'N/A'},
#     'COLUMNS': 43,
#     'INTERCHANGE_FORMAT': 'BINARY',
#     'ROWS': 38,
#     'ROW_BYTES': 166})
#   ('SP_SPECTRUM_WAV',
#    {'IMAGE_VALUE_TYPE': 'WAVELENGTH',
#     'LINES': 1,
#     'LINE_SAMPLES': 296,
#     'OFFSET': 0.0,
#     'SAMPLE_BITS': 16,
#     'SAMPLE_TYPE': 'MSB_UNSIGNED_INTEGER',
#     'SCALING_FACTOR': 0.1,
#     'UNIT': 'nm'})
#   ('SP_SPECTRUM_RAW',
#    {'IMAGE_VALUE_TYPE': 'RAW_DN',
#     'LINES': 38,
#     'LINE_SAMPLES': 296,
#     'OFFSET': 'N/A',
#     'SAMPLE_BITS': 16,
#     'SAMPLE_TYPE': 'MSB_UNSIGNED_INTEGER',
#     'SCALING_FACTOR': 'N/A',
#     'UNIT': 'ND'})
#   ('SP_SPECTRUM_REF2',
#    {'IMAGE_VALUE_TYPE': 'REFLECTANCE',
#     'LINES': 38,
#     'LINE_SAMPLES': 296,
#     'OFFSET': 0.0,
#     'SAMPLE_BITS': 16,
#     'SAMPLE_TYPE': 'MSB_UNSIGNED_INTEGER',
#     'SCALING_FACTOR': 0.0001,
#     'UNIT': 'ND'})
#   ('SP_SPECTRUM_RAD',
#    {'IMAGE_VALUE_TYPE': 'RADIANCE',
#     'LINES': 38,
#     'LINE_SAMPLES': 296,
#     'OFFSET': 0.0,
#     'SAMPLE_BITS': 16,
#     'SAMPLE_TYPE': 'MSB_UNSIGNED_INTEGER',
#     'SCALING_FACTOR': 0.01,
#     'UNIT': 'W/m**2/micron/sr'})
#   ('SP_SPECTRUM_REF1',
#    {'IMAGE_VALUE_TYPE': 'REFLECTANCE',
#     'LINES': 38,
#     'LINE_SAMPLES': 296,
#     'OFFSET': 0.0,
#     'SAMPLE_BITS': 16,
#     'SAMPLE_TYPE': 'MSB_UNSIGNED_INTEGER',
#     'SCALING_FACTOR': 0.0001,
#     'UNIT': 'ND'})
#   ('SP_SPECTRUM_QA',
#    {'IMAGE_VALUE_TYPE': 'QUALITY',
#     'LINES': 38,
#     'LINE_SAMPLES': 296,
#     'OFFSET': 0.0,
#     'SAMPLE_BITS': 16,
#     'SAMPLE_TYPE': 'MSB_UNSIGNED_INTEGER',
#     'SCALING_FACTOR': 1.0,
#     'UNIT': 'N/A'})
#   ('L2D_RESULT_ARRAY',
#    {'IMAGE_VALUE_TYPE': 'N/A',
#     'LINES': 0,
#     'LINE_SAMPLES': 0,
#     'OFFSET': 'N/A',
#     'SAMPLE_BITS': 0,
#     'SAMPLE_TYPE': 'N/A',
#     'SCALING_FACTOR': 'N/A',
#     'UNIT': 'N/A'})
# ])

# %%
s.ancillary_data.head(5)
# Out:
#    SPACECRAFT_CLOCK_COUNT  VIS_FOCAL_PLANE_TEMPERATURE  \
# 0            9.148317e+08                        13.48
# 1            9.148317e+08                        13.48
# 2            9.148317e+08                        13.48
# 3            9.148317e+08                        13.48
# 4            9.148317e+08                        13.48
#
#    NIR1_FOCAL_PLANE_TEMPERATURE  NIR2_FOCAL_PLANE_TEMPERATURE  \
# 0                         10.33                         243.0
# 1                         10.33                         243.0
# 2                         10.25                         243.0
# 3                         10.33                         243.0
# 4                         10.33                         243.0
#
#    SPECTROMETER_TEMPERATURE_1  SPECTROMETER_TEMPERATURE_2  \
# 0                       10.41                        14.3
# 1                       10.41                        14.3
# 2                       10.41                        14.3
# 3                       10.41                        14.3
# 4                       10.41                        14.3
#
#    SPECTROMETER_TEMPERATURE_3  SPECTROMETER_TEMPERATURE_4  \
# 0                       10.81                   17.049999
# 1                       10.81                   17.049999
# 2                       10.81                   17.049999
# 3                       10.81                   17.049999
# 4                       10.81                   17.049999
#
#    HALOGEN_BULB_RADIANCE  HALOGEN_BULB_VOLTAGE1            ...              \
# 0                  4.759                  4.759            ...
# 1                  4.759                  4.759            ...
# 2                  4.759                  4.759            ...
# 3                  4.759                  4.759            ...
# 4                  4.759                  4.759            ...
#
#    CALIBRATION  SP_PELTIER  TC_MI_STATUS  CLOCK_COUNT_ERR_FLAG  \
# 0            0           1             1                     0
# 1            0           1             1                     0
# 2            0           1             1                     0
# 3            0           1             1                     0
# 4            0           1             1                     0
#
#    SPATIAL_RESOLUTION_FLAG  GEOMETRIC_INFO_RECAL_FLAG  \
# 0                       66                         67
# 1                       66                         67
# 2                       66                         67
# 3                       66                         67
# 4                       66                         67
#
#    SUPPORT_IMAGE_LINE_POSITION  SUPPORT_IMAGE_COLUMN_POSITION  \
# 0                           27                            478
# 1                           55                            478
# 2                           83                            478
# 3                          112                            478
# 4                          140                            478
#
#    THUMBNAIL_LINE_POSITION  THUMBNAIL_COLUMN_POSITION
# 0                       13                        230
# 1                       27                        230
# 2                       40                        230
# 3                       53                        230
# 4                       66                        230
#
# [5 rows x 43 columns]

# %%
s.spectra[0].head(5)
# Out:
#           RAW    REF1    REF2     QA
# 512.6  3639.0  0.0000  0.0000  393.0
# 518.4  3631.0  0.0000  0.0000  393.0
# 524.7  3639.0  0.0000  0.0000  385.0
# 530.4  3632.0  0.0015  6.5531  393.0
# 536.5  3647.0  0.0015  6.5531  385.0

# %% [markdown]
# ## Spectra
# Spectra are a pandas panel. This particular data collection has 38 individual spectra with 269 different wavelengths and 4 different data collected (RAW, REF1, REF2, QA).  The ancillary data contains 38 individual entries that map to the 38 different spectral panels.
#
# Therefore, each observation is composed of:
#
# * a panel from the spectra object: `s.spectra[i]`
# * an associated row from the ancillary data object: `s.ancillarydata.iloc[i]`
# * the file name `s.input_data`
# * the image label metadata `s.label`
#
# The above 4 items are what need to be stored within the DBs.

# %%
s.spectra.shape
# Out:
# (38, 269, 4)

# %%
s.ancillary_data.shape
# Out:
# (38, 43)

# %%
s.input_data
# Out:
# 'SP_2C_02_05494_N704_E2143.spc'
